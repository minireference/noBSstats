# %% [markdown]
# # Practical data exercises
#
# This notebook contains all solutions of the exercises from **Section 1.2 Data in practice** in the **No Bullshit Guide to Statistics**.

# %% [markdown]
# ### Notebooks setup

# %%
# Ensure required Python modules are installed
# %pip install --quiet numpy seaborn pandas ministats
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# Simplified int and float __repr__
import numpy as np
np.set_printoptions(legacy='1.25')

# %%
# Download datasets/ directory if necessary
from ministats import ensure_datasets
ensure_datasets()
# Out:
# datasets/ directory already exists.

# %% [markdown]
# ### E1.5
#
# Create a new Python 3 notebook and use a code cell to compute the sum of `3456` and `789`.

# %% [markdown]
# ### E1.6
#
# How many seconds are there in one day?
#
# Hint: One min has 60 secs; one hour has 60 mins; one day has 24 h.
#
# Use the code cell below to write a Python expression
# then press **SHIFT**+**ENTER** to run the code cell.

# %%
# put your answer here

# %% [markdown]
# ### E1.7
#
# Open the data file [`datasets/players.csv`](http://nobsstats.com/datasets/players.csv)
# using [LibreOffice](https://www.libreoffice.org/)
# or another spreadsheet program.
# Compute the mean and the standard deviation of the variable `age` using spreadsheet functions.
#
# Hint: Use the spreadsheet functions `AVERAGE()` and `STDEV()`.

# %%
# Use spreadsheet software like LibreOffice, Excel, Google Sheets

# %% [markdown]
# ### E1.8
#
# Use the Pandas function `pd.read_csv()` to load the players dataset,
# then use the Pandas methods `.mean()` and `.std()`
# to compute the mean and the standard deviation of the variable `points`.

# %% [markdown]
# ### E1.9
#
# Load the doctors dataset from the file `datasets/doctors.csv`.
# Use the data frame method `.head()` to print the first three rows,
# and access the `.shape` attribute to see the number of rows and columns.

# %% [markdown]
# ### E1.10
#
# Load students dataset (`datasets/students.csv`)
# and compute the mean and standard deviation of the variable `score`.

# %% [markdown]
# ### E1.11
#
# Create a strip plot of the variable `age` from the players dataset.

# %%
import pandas as pd
players = pd.read_csv("datasets/players.csv")

import seaborn as sns
# generate strip plot

# %% [markdown]
# ### E1.12
#
# Generate a strip plot of the variable `age` from the players dataset
# that represents the variable `finished` as the points' colour.

# %% [markdown]
# ### E1.13
#
# Load the students dataset (`datasets/students.csv`)
# and compute the mean of the variable `effort`.

# %% [markdown]
# ### E1.14
#
# Load the students dataset (`datasets/students.csv`)
# and compute the means of the variable `effort`
# for students in the `lecture` and `debate` curriculum variants.

# %%
import pandas as pd
students = pd.read_csv("datasets/students.csv")
lstudents = ... # select students where students["curriculum"]=="lecture"

# %%
dstudents = ... # select students where students["curriculum"]=="debate"

# %% [markdown]
# ### E1.15
#
# Load the kombucha dataset from `datasets/kombucha.csv`
# and extract the kombucha volume measurements from Batch 10,
# storing the result in a new variable called `ksample10`.
#
# - **a)** Generate a strip plot of `ksample10`.
# - **b)** Compute the mean and the standard deviation of `ksample10`.
# - **c)** Select the subset of values in `ksample10` that are less than 1050 and store your result as `ksample10_clean`.
# - **d)** Compute the mean and the standard deviation of `ksample10_clean`.

# %%
import pandas as pd
kombucha = pd.read_csv("datasets/kombucha.csv")
ksample10 = ...  # select volumes from Batch 10

# %%
ksample_clean = ...  # subset of volumes ksample10 that are < 1050
