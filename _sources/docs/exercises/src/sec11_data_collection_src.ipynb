# %% [markdown]
# # Section 1.1 — Data collection exercises
#
# This notebook contains exercises and solutions from **Section 1.1 Data collection** in the **No Bullshit Guide to Statistics**.

# %% [markdown]
# ### Notebooks setup

# %% [markdown]
# ### E1.1
#
# TODO

# %% [markdown]
# ### E1.2
#
# TODO

# %% [markdown]
# ### E1.3
#
# TODO

# %% [markdown]
# ### E1.4
#
# TODO
