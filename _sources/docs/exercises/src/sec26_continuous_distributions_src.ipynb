# %% [markdown]
# # Exercises for Section 2.6 Inventory of continuous distributions
#
# This notebook contains the exercises from [Section 2.6 Inventory of continuous distributions](https://minireference.com/static/excerpts/noBSstats_part1_preview.pdf#page=71) of the **No Bullshit Guide to Statistics**.

# %% [markdown]
# ### Notebooks setup

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Figures setup
sns.set_theme(
    context="paper",
    style="whitegrid",
    palette="colorblind",
    rc={'figure.figsize': (5,3)},
)
# %config InlineBackend.figure_format = 'retina'

# %%
# Simple float __repr__
import numpy as np
if int(np.__version__.split(".")[0]) >= 2:
    np.set_printoptions(legacy='1.25')

# %% [markdown]
# ## Exercies

# %% [markdown]
# ### E2.42

# %%
# @studentprompt

# %%
# @solution

# %% [markdown]
# ### E2.43

# %%
# @studentprompt

# %%
# @solution

# %% [markdown]
# ### E2.44

# %%
# @studentprompt

# %%
# @solution

# %% [markdown]
# ### E2.45 {exercise:hard-disk-failures-expon-and-gamma}

# %%
# @studentprompt

# %%
# @solution
from scipy.stats import expon

rvW = expon(loc=0,scale=1/20)

rvW.cdf(10/30.44)
# Out:
# 0.9985986261945486

# %%
from scipy.stats import gamma as gammadist
rvW3 = gammadist(a=3, loc=0, scale=1/20)
rvW3.cdf(10/30.44)
# Out:
# 0.9591433139232212

# %% [markdown]
# ### E2.46

# %%
# @studentprompt

# %%
# @solution

# %% [markdown]
# ### E2.47

# %%
# @studentprompt

# %%
# @solution
from scipy.stats import t as tdist
rvT = tdist(df=7)

# %%
# @solution
# a)
rvT.mean(), rvT.var()
# Out:
# (0.0, 1.4)

# %%
# @solution
# b)
1 - rvT.cdf(2)
# Out:
# 0.042809664281488025

# %%
# @solution
# b)
[rvT.ppf(0.025), rvT.ppf(0.975)]
# Out:
# [-2.3646242515927844, 2.364624251592784]

# %% [markdown]
# ### E2.48

# %%
# @studentprompt

# %%
# @solution
from scipy.stats import chi2
rvQ = chi2(df=3)

# %%
# @solution
# b)
rvQ.mean(), rvQ.var()
# Out:
# (3.0, 6.0)

# %%
# @solution
# c)
1 - rvQ.cdf(3)
# Out:
# 0.39162517627108906

# %%
# @solution
# d)
[rvQ.ppf(0.05), rvQ.ppf(0.95)]
# Out:
# [0.35184631774927144, 7.8147279032511765]

# %% [markdown]
# ### E2.49

# %%
# @studentprompt
from scipy.stats import f as fdist
rvR = fdist(dfn=2, dfd=5)

# %%
# @solution
# b)
rvR.mean(), rvR.var()
# Out:
# (1.6666666666666667, 13.88888888888889)

# %%
# @solution
# c)
1 - rvR.cdf(3)
# Out:
# 0.13929749224447152

# %%
# @solution
# d)
[rvR.ppf(0.05), rvR.ppf(0.95)]
# Out:
# [0.05182311207284406, 5.786135043349964]
