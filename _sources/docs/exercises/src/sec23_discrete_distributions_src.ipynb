# %% [markdown]
# # Exercises for Section 2.3 Inventory of discrete distributions
#
# This notebook contains the exercises from [Section 2.3 Inventory of discrete distributions](https://minireference.com/static/excerpts/noBSstats_part1_preview.pdf#page=55) of the **No Bullshit Guide to Statistics**.

# %% [markdown]
# ### Notebooks setup

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Figures setup
sns.set_theme(
    context="paper",
    style="whitegrid",
    palette="colorblind",
    rc={'figure.figsize': (4,2)},
)

# %config InlineBackend.figure_format = 'retina'

# %%
# Simple float __repr__
import numpy as np
if int(np.__version__.split(".")[0]) >= 2:
    np.set_printoptions(legacy='1.25')

# %% [markdown]
# ## Exercies

# %% [markdown]
# ### E2.24

# %%
# @studentprompt

# %%
# @solution

# %% [markdown]
# ### E2.25

# %%
# @studentprompt

# %%
# @solution

# %% [markdown]
# ### E2.26

# %%
# @studentprompt

# %%
# @solution

# %% [markdown]
# ### E2.27

# %%
# @studentprompt

# %%
# @solution

# %% [markdown]
# ### E2.28

# %%
# @studentprompt

# %%
# @solution

# %% [markdown]
# ### E2.29

# %%
# @studentprompt

# %%
# @solution
